# %%
import numpy as np
import matplotlib as mpl

# %%
np.__version__
# Out:
# '1.24.2'

# %%
mpl.__version__
# Out:
# '3.7.0'

# %%
import matplotlib.pyplot as plt

# %%
y = [3, 6, 1, 8, 9]
plt.plot(y)
plt.show()
